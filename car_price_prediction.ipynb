# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\aa\OneDrive\Documents\Project\Vehicle Data\car data.csv')

# %%
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
df.shape
# Out:
# (301, 9)

# %%
df.dtypes
# Out:
# Car_Name          object
# Year               int64
# Selling_Price    float64
# Present_Price    float64
# Kms_Driven         int64
# Fuel_Type         object
# Seller_Type       object
# Transmission      object
# Owner              int64
# dtype: object

# %%
# it seems that fuel_type, Seller_type, Transmission,Car_name are categorical variables
print(df['Fuel_Type'].unique())
print(df['Seller_Type'].unique())
print(df['Transmission'].unique())
print(df['Owner'].unique())
print(len(df['Car_Name'].unique()))
# Out:
# ['Petrol' 'Diesel' 'CNG']
# ['Dealer' 'Individual']
# ['Manual' 'Automatic']
# [0 1 3]
# 98

# %%
df.describe()
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.644115   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %%
# we seee that car names would not play much significant role while predicting present seling price
print(df.columns)
final_dataset = df.drop('Car_Name',axis=1)
# Out:
# Index(['Car_Name', 'Year', 'Selling_Price', 'Present_Price', 'Kms_Driven',
#        'Fuel_Type', 'Seller_Type', 'Transmission', 'Owner'],
#       dtype='object')

# %%
final_dataset.columns
# Out:
# Index(['Year', 'Selling_Price', 'Present_Price', 'Kms_Driven', 'Fuel_Type',
#        'Seller_Type', 'Transmission', 'Owner'],
#       dtype='object')

# %%
final_dataset.columns
# Out:
# Index(['Year', 'Selling_Price', 'Present_Price', 'Kms_Driven', 'Fuel_Type',
#        'Seller_Type', 'Transmission', 'Owner'],
#       dtype='object')

# %%
# deriving new feature
final_dataset['Current Year']=2021

# %%
final_dataset['No_years']=final_dataset['Current Year']-final_dataset['Year']

# %%
final_dataset.head()
# Out:
#    Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0  2014           3.35           5.59       27000    Petrol      Dealer
# 1  2013           4.75           9.54       43000    Diesel      Dealer
# 2  2017           7.25           9.85        6900    Petrol      Dealer
# 3  2011           2.85           4.15        5200    Petrol      Dealer
# 4  2014           4.60           6.87       42450    Diesel      Dealer
#
#   Transmission  Owner  Current Year  No_years
# 0       Manual      0          2021         7
# 1       Manual      0          2021         8
# 2       Manual      0          2021         4
# 3       Manual      0          2021        10
# 4       Manual      0          2021         7

# %%
final_dataset.drop(['Year','Current Year'],axis=1,inplace=True)
final_dataset.head()
# Out:
#    Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0           3.35           5.59       27000    Petrol      Dealer
# 1           4.75           9.54       43000    Diesel      Dealer
# 2           7.25           9.85        6900    Petrol      Dealer
# 3           2.85           4.15        5200    Petrol      Dealer
# 4           4.60           6.87       42450    Diesel      Dealer
#
#   Transmission  Owner  No_years
# 0       Manual      0         7
# 1       Manual      0         8
# 2       Manual      0         4
# 3       Manual      0        10
# 4       Manual      0         7

# %%
# now how do we convert this categorical variables into numeric data
# using one_hot encoding by get_dummy functions in pandas
final_dataset=pd.get_dummies(final_dataset,drop_first=True)
final_dataset.head()
# so categorical variables converted to numeric
# Out:
#    Selling_Price  Present_Price  Kms_Driven  Owner  No_years  \
# 0           3.35           5.59       27000      0         7
# 1           4.75           9.54       43000      0         8
# 2           7.25           9.85        6900      0         4
# 3           2.85           4.15        5200      0        10
# 4           4.60           6.87       42450      0         7
#
#    Fuel_Type_Diesel  Fuel_Type_Petrol  Seller_Type_Individual  \
# 0                 0                 1                       0
# 1                 1                 0                       0
# 2                 0                 1                       0
# 3                 0                 1                       0
# 4                 1                 0                       0
#
#    Transmission_Manual
# 0                    1
# 1                    1
# 2                    1
# 3                    1
# 4                    1

# %%
final_dataset.corr()
# Out:
#                         Selling_Price  Present_Price  Kms_Driven     Owner  \
# Selling_Price                1.000000       0.878983    0.029187 -0.088344
# Present_Price                0.878983       1.000000    0.203647  0.008057
# Kms_Driven                   0.029187       0.203647    1.000000  0.089216
# Owner                       -0.088344       0.008057    0.089216  1.000000
# No_years                    -0.236141       0.047584    0.524342  0.182104
# Fuel_Type_Diesel             0.552339       0.473306    0.172515 -0.053469
# Fuel_Type_Petrol            -0.540571      -0.465244   -0.172874  0.055687
# Seller_Type_Individual      -0.550724      -0.512030   -0.101419  0.124269
# Transmission_Manual         -0.367128      -0.348715   -0.162510 -0.050316
#
#                         No_years  Fuel_Type_Diesel  Fuel_Type_Petrol  \
# Selling_Price          -0.236141          0.552339         -0.540571
# Present_Price           0.047584          0.473306         -0.465244
# ...

# %%
# for seeing correlation graph
import seaborn as sns

# %%
sns.pairplot(final_dataset)

# %%
# correlation can't be seen in good amount from above plots
# so we can use heatmap
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
corrmat=final_dataset.corr()
top_corr_features=corrmat.index
plt.figure(figsize=(20,20))
# plotting heatmap

g=sns.heatmap(final_dataset[top_corr_features].corr(),annot=True,cmap='RdYlGn')

# %% [markdown]
# we can see that selling price and present price are highly positively correlated
#
# whereas fyel_type_petrol and fuel_type_diesel are higly negatively correlated

# %%
final_dataset.head()
# Out:
#    Selling_Price  Present_Price  Kms_Driven  Owner  No_years  \
# 0           3.35           5.59       27000      0         7
# 1           4.75           9.54       43000      0         8
# 2           7.25           9.85        6900      0         4
# 3           2.85           4.15        5200      0        10
# 4           4.60           6.87       42450      0         7
#
#    Fuel_Type_Diesel  Fuel_Type_Petrol  Seller_Type_Individual  \
# 0                 0                 1                       0
# 1                 1                 0                       0
# 2                 0                 1                       0
# 3                 0                 1                       0
# 4                 1                 0                       0
#
#    Transmission_Manual
# 0                    1
# 1                    1
# 2                    1
# 3                    1
# 4                    1

# %%
# Selling_Price is our dependent feature which have to be predicted
X = final_dataset.iloc[:,1:]
Y = final_dataset.iloc[:,0]

# %%
X.head()
# Out:
#    Present_Price  Kms_Driven  Owner  No_years  Fuel_Type_Diesel  \
# 0           5.59       27000      0         7                 0
# 1           9.54       43000      0         8                 1
# 2           9.85        6900      0         4                 0
# 3           4.15        5200      0        10                 0
# 4           6.87       42450      0         7                 1
#
#    Fuel_Type_Petrol  Seller_Type_Individual  Transmission_Manual
# 0                 1                       0                    1
# 1                 0                       0                    1
# 2                 1                       0                    1
# 3                 1                       0                    1
# 4                 0                       0                    1

# %%
### feature importance - which features are more important
from sklearn.ensemble import ExtraTreesRegressor
model=ExtraTreesRegressor()
model.fit(X,Y)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-26-1a67b1e50bb4> in <module>
#       1 ### feature importance - which features are more important
# ----> 2 from sklearn.ensemble import ExtraTreesRegressor
#       3 model=ExtraTreesRegressor()
#       4 model.fit(X,Y)
#
# ModuleNotFoundError: No module named 'sklearn'
